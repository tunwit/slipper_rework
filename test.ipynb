# %%
import pandas as pd

dfs_raw = pd.read_excel("5.68.xlsx", header=1, sheet_name=None)
for i,df in dfs_raw.items():
    print(df.dropna(subset="ชื่อเล่น"))
# Out:
#     ลำดับ                                 ชื่อ-นามสกุล      ชื่อเล่น  \
# 0     1.0                             นาย อดิสรณ์ มีพบ           รอน
# 1     2.0                        ต่วนมีด๊ะ  เสะอุเซ็ง        ซันเดย์
# 2     3.0                                    Channy La           น้ำ
# 3     4.0                                          TAK          ตั๊ก
# 4     5.0                            Sokcheat chhoeurm        เจี๊ยบ
# 5     6.0                                     DAVY LAY          ดาวี
# 6     7.0                   นางสาว จิราภา มั่งมีทรัพย์           แนท
# 7     8.0                                   Leng Sitra         พิมพ์
# 8     9.0  ชานน ไชยะสาน (Chanon Chaisan) nam xayyasane          ต่าย
# 9    10.0                        นาย เมธาวี ทัศน์จันดา          แม็ก
# 10   11.0                            ราเชนทร์ วุฒิวงศ์           เซน
# 11   12.0                            อับดุลเลาะห์ อาแว       บังเลาะ
# 12   13.0                                 Kyaw Ye Htut        เมาเล่
# ...
